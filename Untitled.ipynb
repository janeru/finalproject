# %%
print(1)
# Out:
# 1

# %%
print('the weather is well')
# Out:
# the weather is well

# %%
print(1+3)
# Out:
# 4

# %%
print('1'+'3')
# Out:
# 13

# %%
import pandas
pandas.read_csv
# Out:
# <function pandas.io.parsers._make_parser_function.<locals>.parser_f(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, skipfooter=0, doublequote=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)>

# %%
import pandas

# %%
pandas.read_csv('C:\\Users\\EELab507\\Desktop\\20180719\\newimm_d .CSV',encoding='ANSI')
# Out:
#    臺北市新移民統計            Unnamed: 1                    Unnamed: 2   Unnamed: 3  \
# 0      序\n號                  統計項目                           NaN       填報\n機關
# 1       NaN                   NaN                           NaN          NaN
# 2         1             新移民人口結構比率                           NaN          民政局
# 3       NaN                   NaN                      大陸港澳配偶比率          民政局
# 4       NaN                   NaN                      其他外籍配偶比率          民政局
# 5       NaN                   NaN                         越南籍配偶          民政局
# 6       NaN                   NaN                         日本籍配偶          民政局
# 7       NaN                   NaN                         美國籍配偶          民政局
# 8       NaN                   NaN                         印尼籍配偶          民政局
# 9       NaN                   NaN                         韓國籍配偶          民政局
# 10      NaN                   NaN                        加拿大籍配偶          民政局
# ...

# %%
import pandas
pandas.read_csv('C:\\Users\\EELab507\\Desktop\\20180719\\taipeifireworkpot.csv,encoding='BIG5')
# Out:
#   File "<ipython-input-40-425451e353ed>", line 2
#     pandas.read_csv('C:\\Users\\EELab507\\Desktop\\20180719\\taipeifireworkpot.csv,encoding='BIG5')
#                                                                                                 ^
# SyntaxError: invalid syntax

# %%
import pandas
pandas.read_csv('C:\\Users\\EELab507\\Desktop\\20180719\\taipeifireworkpot.csv,encoding='ANSI')
# Out:
#   File "<ipython-input-42-f9d2e22b7371>", line 2
#     pandas.read_csv('C:\\Users\\EELab507\\Desktop\\20180719\\taipeifireworkpot.csv,encoding='ANSI')
#                                                                                                 ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df=pd.read_csv('taipeifireworkpot.csv',encoding='big5')
print(df)
# Out:
#      分隊名稱     X97      Y97
# 0    古亭分隊  304296  2767192
# 1    華山分隊  302552  2771114
# 2    忠孝分隊  303184  2770719
# 3    泉州分隊  301717  2768601
# 4    城中分隊  301807  2771076
# 5    雙園分隊  300004  2769060
# 6    龍山分隊  300137  2770145
# 7    萬芳分隊  307177  2766126
# 8    景美分隊  304631  2765034
# 9    木柵分隊  306876  2764656
# 10   寶橋分隊  306021  2763666
# 11   金華分隊  303258  2769481
# 12   安和分隊  305731  2769536
# 13   復興分隊  304827  2769217
# 14   南港分隊  311271  2771970
# 15   舊莊分隊  312085  2770911
# 16   信義分隊  307391  2770418
# 17   永吉分隊  307433  2770941
# 18   莊敬分隊  307040  2769197
# 19   成德分隊  309230  2771216
# 20   大直分隊  306136  2774777
# 21   松江分隊  303875  2771146
# 22   圓山分隊  303386  2773471
# 23   八德分隊  306804  2771272
# 24   中崙分隊  305076  2771247
# 25   東湖分隊  311835  2773391
# 26   大湖分隊  310690  2775204
# 27   內湖分隊  309559  2773607
# 28   民權分隊  308283  2773311
# 29   建國分隊  304063  2773398
# 30   建成分隊  302289  2771942
# 31   延平分隊  301597  2771439
# 32   大同分隊  301831  2772685
# ...

# %%
import pandas as pd
df=pd.read_csv('newimm_d .CSV',encoding='ANSI')
print(df)
# Out:
#    臺北市新移民統計            Unnamed: 1                    Unnamed: 2   Unnamed: 3  \
# 0      序\n號                  統計項目                           NaN       填報\n機關
# 1       NaN                   NaN                           NaN          NaN
# 2         1             新移民人口結構比率                           NaN          民政局
# 3       NaN                   NaN                      大陸港澳配偶比率          民政局
# 4       NaN                   NaN                      其他外籍配偶比率          民政局
# 5       NaN                   NaN                         越南籍配偶          民政局
# 6       NaN                   NaN                         日本籍配偶          民政局
# 7       NaN                   NaN                         美國籍配偶          民政局
# 8       NaN                   NaN                         印尼籍配偶          民政局
# 9       NaN                   NaN                         韓國籍配偶          民政局
# 10      NaN                   NaN                        加拿大籍配偶          民政局
# ...

# %%
import pandas 
df=pd.read_csv('taipeifireworkpot.csv',encoding='big5')
df
# Out:
#      分隊名稱     X97      Y97
# 0    古亭分隊  304296  2767192
# 1    華山分隊  302552  2771114
# 2    忠孝分隊  303184  2770719
# 3    泉州分隊  301717  2768601
# 4    城中分隊  301807  2771076
# 5    雙園分隊  300004  2769060
# 6    龍山分隊  300137  2770145
# 7    萬芳分隊  307177  2766126
# 8    景美分隊  304631  2765034
# 9    木柵分隊  306876  2764656
# 10   寶橋分隊  306021  2763666
# 11   金華分隊  303258  2769481
# 12   安和分隊  305731  2769536
# 13   復興分隊  304827  2769217
# 14   南港分隊  311271  2771970
# 15   舊莊分隊  312085  2770911
# 16   信義分隊  307391  2770418
# 17   永吉分隊  307433  2770941
# 18   莊敬分隊  307040  2769197
# 19   成德分隊  309230  2771216
# 20   大直分隊  306136  2774777
# 21   松江分隊  303875  2771146
# 22   圓山分隊  303386  2773471
# 23   八德分隊  306804  2771272
# 24   中崙分隊  305076  2771247
# 25   東湖分隊  311835  2773391
# 26   大湖分隊  310690  2775204
# 27   內湖分隊  309559  2773607
# 28   民權分隊  308283  2773311
# 29   建國分隊  304063  2773398
# 30   建成分隊  302289  2771942
# 31   延平分隊  301597  2771439
# 32   大同分隊  301831  2772685
# ...

# %%
import pandas 
df=pd.read_csv('FIFA.csv',encoding='big5')
df
# Out:
#            Date            Team        Opponent  Goal Scored  \
# 0    14-06-2018          Russia    Saudi Arabia            5
# 1    14-06-2018    Saudi Arabia          Russia            0
# 2    15-06-2018           Egypt         Uruguay            0
# 3    15-06-2018         Uruguay           Egypt            1
# 4    15-06-2018         Morocco            Iran            0
# 5    15-06-2018            Iran         Morocco            1
# 6    15-06-2018        Portugal           Spain            3
# 7    15-06-2018           Spain        Portugal            3
# 8    16-06-2018          France       Australia            2
# 9    16-06-2018       Australia          France            1
# 10   16-06-2018       Argentina         Iceland            1
# 11   16-06-2018         Iceland       Argentina            1
# 12   16-06-2018            Peru         Denmark            0
# 13   16-06-2018         Denmark            Peru            1
# ...

# %%
dfbew=df[df['Ball Possession %'],41]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-31a3e1bf5554> in <module>()
# ----> 1 dfbew=df[df['Ball Possession %'],41]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2482         """Return the cached item, item represents a label indexer."""
# ...

# %%
dfbew=df[df['Ball Possession %']<41]

# %%
dfbew.head()
# Out:
#           Date      Team      Opponent  Goal Scored  Ball Possession %  \
# 0   14-06-2018    Russia  Saudi Arabia            5                 40
# 5   15-06-2018      Iran       Morocco            1                 36
# 6   15-06-2018  Portugal         Spain            3                 39
# 11  16-06-2018   Iceland     Argentina            1                 28
# 19  17-06-2018    Mexico       Germany            1                 40
#
#     Attempts  On-Target  Off-Target  Blocked  Corners      ...        \
# 0         13          7           3        3        6      ...
# 5          8          2           5        1        2      ...
# 6          8          3           2        3        4      ...
# 11         9          3           5        1        2      ...
# 19        12          4           6        2        1      ...
#
#     Yellow Card  Yellow & Red  Red  Man of the Match  1st Goal        Round  \
# ...

# %%
dfbew['item']=0
# Out:
# C:\Users\EELab507\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfbew=df[df['Ball Possession %	'].between(41,48)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ball Possession %\t'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-22b3903b6997> in <module>()
# ...

# %%
dfbew1=df[df['Ball Possession %'].between(41,48)]

# %%
dfbew1['item']=1
# Out:
# C:\Users\EELab507\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfbew=df[df['Ball Possession %']<42]

# %%
dfbew
# Out:
#            Date            Team      Opponent  Goal Scored  Ball Possession %  \
# 0    14-06-2018          Russia  Saudi Arabia            5                 40
# 5    15-06-2018            Iran       Morocco            1                 36
# 6    15-06-2018        Portugal         Spain            3                 39
# 11   16-06-2018         Iceland     Argentina            1                 28
# 19   17-06-2018          Mexico       Germany            1                 40
# 25   18-06-2018          Panama       Belgium            0                 39
# 26   18-06-2018         Tunisia       England            1                 41
# 28   19-06-2018        Colombia         Japan            1                 41
# 38   20-06-2018            Iran         Spain            0                 30
# 47   22-06-2018      Costa Rica        Brazil            0                 34
# 54   23-06-2018  Korea Republic        Mexico            1                 41
# ...

# %%
dfbew['item']=0
# Out:
# C:\Users\EELab507\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfbew1=df[df['Ball Possession %'].between(42,48)]

# %%
dfbew1
# Out:
#            Date            Team      Opponent  Goal Scored  Ball Possession %  \
# 2    15-06-2018           Egypt       Uruguay            0                 43
# 13   16-06-2018         Denmark          Peru            1                 48
# 15   17-06-2018         Nigeria       Croatia            0                 46
# 21   17-06-2018     Switzerland        Brazil            1                 48
# 23   18-06-2018  Korea Republic        Sweden            0                 48
# 31   19-06-2018         Senegal        Poland            2                 43
# 32   19-06-2018          Russia         Egypt            3                 47
# 34   20-06-2018        Portugal       Morocco            1                 47
# 36   20-06-2018         Uruguay  Saudi Arabia            1                 47
# 42   21-06-2018          France          Peru            1                 44
# 45   21-06-2018         Croatia     Argentina            3                 42
# ...

# %%
dfbew1['item']=1
# Out:
# C:\Users\EELab507\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfbew2=df[df['Ball Possession %'].between(49,57)]

# %%
dfbew2
# Out:
#            Date          Team        Opponent  Goal Scored  Ball Possession %  \
# 3    15-06-2018       Uruguay           Egypt            1                 57
# 8    16-06-2018        France       Australia            2                 51
# 9    16-06-2018     Australia          France            1                 49
# 12   16-06-2018          Peru         Denmark            0                 52
# 14   17-06-2018       Croatia         Nigeria            2                 54
# 16   17-06-2018    Costa Rica          Serbia            0                 50
# 17   17-06-2018        Serbia      Costa Rica            1                 50
# 20   17-06-2018        Brazil     Switzerland            1                 52
# 22   18-06-2018        Sweden  Korea Republic            1                 52
# 30   19-06-2018        Poland         Senegal            1                 57
# 33   19-06-2018         Egypt          Russia            1                 53
# ...

# %%
dfbew2['item']=2
# Out:
# C:\Users\EELab507\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfbew3=df[df['Ball Possession %']>57]

# %%
dfbew3
# Out:
#            Date          Team        Opponent  Goal Scored  Ball Possession %  \
# 1    14-06-2018  Saudi Arabia          Russia            0                 60
# 4    15-06-2018       Morocco            Iran            0                 64
# 7    15-06-2018         Spain        Portugal            3                 61
# 10   16-06-2018     Argentina         Iceland            1                 72
# 18   17-06-2018       Germany          Mexico            0                 60
# 24   18-06-2018       Belgium          Panama            3                 61
# 27   18-06-2018       England         Tunisia            2                 59
# 29   19-06-2018         Japan        Colombia            2                 59
# 39   20-06-2018         Spain            Iran            1                 70
# 44   21-06-2018     Argentina         Croatia            0                 58
# 46   22-06-2018        Brazil      Costa Rica            2                 66
# ...

# %%
dfbew3['item']=3
# Out:
# C:\Users\EELab507\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new=pd.concat([dfbew,dfbew1,dfbew2,dfbew3])

# %%
new.head()
# Out:
#           Date      Team      Opponent  Goal Scored  Ball Possession %  \
# 0   14-06-2018    Russia  Saudi Arabia            5                 40
# 5   15-06-2018      Iran       Morocco            1                 36
# 6   15-06-2018  Portugal         Spain            3                 39
# 11  16-06-2018   Iceland     Argentina            1                 28
# 19  17-06-2018    Mexico       Germany            1                 40
#
#     Attempts  On-Target  Off-Target  Blocked  Corners  ...   Yellow & Red  \
# 0         13          7           3        3        6  ...              0
# 5          8          2           5        1        2  ...              0
# 6          8          3           2        3        4  ...              0
# 11         9          3           5        1        2  ...              0
# 19        12          4           6        2        1  ...              0
#
#     Red  Man of the Match  1st Goal        Round  PSO  Goals in PSO  \
# ...

# %%
new
# Out:
#            Date            Team        Opponent  Goal Scored  \
# 0    14-06-2018          Russia    Saudi Arabia            5
# 5    15-06-2018            Iran         Morocco            1
# 6    15-06-2018        Portugal           Spain            3
# 11   16-06-2018         Iceland       Argentina            1
# 19   17-06-2018          Mexico         Germany            1
# 25   18-06-2018          Panama         Belgium            0
# 26   18-06-2018         Tunisia         England            1
# 28   19-06-2018        Colombia           Japan            1
# 38   20-06-2018            Iran           Spain            0
# 47   22-06-2018      Costa Rica          Brazil            0
# 54   23-06-2018  Korea Republic          Mexico            1
# 57   23-06-2018          Sweden         Germany            1
# 67   25-06-2018           Egypt    Saudi Arabia            1
# 69   25-06-2018         Morocco           Spain            2
# ...

# %%
dfdata = new.groupby(by='item')['Goal Scored'].sum().to_frame()

# %%
dfdata
# Out:
#       Goal Scored
# item
# 0              44
# 1              33
# 2              40
# 3              52
